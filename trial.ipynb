# %%
import narwhals as nw
import numpy as np
import pytest
import test_aide as ta
from tubular.dates import DatetimeSinusoidCalculator
import tests.test_data as d

# %%
x = nw.from_native(d.create_datediff_test_df())
x.head()
# Out:
# ┌─────────────────────────────────────────────────────┐
# |                 Narwhals DataFrame                  |
# |-----------------------------------------------------|
# |                          a                         b|
# |0 1993-09-27 11:58:58+00:00 2020-05-01 12:59:59+00:00|
# |1 2000-03-19 12:59:59+00:00 2019-12-25 11:58:58+00:00|
# |2 2018-11-10 11:59:59+00:00 2018-11-10 11:59:59+00:00|
# |3 2018-10-10 11:59:59+00:00 2018-11-10 11:59:59+00:00|
# |4 2018-10-10 11:59:59+00:00 2018-09-10 09:59:59+00:00|
# └─────────────────────────────────────────────────────┘

# %%
dt_sinusiod= DatetimeSinusoidCalculator(
    ["a", "b"],
    ["sin", "cos"],
    "month",
    12,
)

# %%
df_2 = dt_sinusiod.transform(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_2 = dt_sinusiod.transform(x)
#
# File ~/.local/lib/python3.9/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/.local/lib/python3.9/site-packages/narwhals/translate.py:733, in narwhalify.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
# ...
